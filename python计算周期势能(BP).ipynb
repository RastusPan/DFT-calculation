# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# 创建一个4x4的矩阵,从上到下依次为AA,AB,AA',AB'
matrix = np.array([
    [1, 2, 2, 4, 4.1893, 4.8626, 3.740],
    [1, 2, -2, -4, 4.1261, 4.8334, 3.402],
    [1, -2 , -2, 4, 4.4197, 4.9315, 3.948],
    [1, -2, 2, -4, 4.591, 4.9505, 3.564]
])
print(matrix)
# Out:
# [[ 1.      2.      2.      4.      4.1893  4.8626  3.74  ]
#  [ 1.      2.     -2.     -4.      4.1261  4.8334  3.402 ]
#  [ 1.     -2.     -2.      4.      4.4197  4.9315  3.948 ]
#  [ 1.     -2.      2.     -4.      4.591   4.9505  3.564 ]]

# %%
D_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 2], matrix[3, 3]]
])
D_determinant = np.linalg.det(D_matrix)

# %%
D1_matrix = np.array([
    [matrix[0, 4], matrix[0, 1], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 4], matrix[1, 1], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 4], matrix[2, 1], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 4], matrix[3, 1], matrix[3, 2], matrix[3, 3]]
])
D1_determinant = np.linalg.det(D1_matrix)

# %%
D5_matrix = np.array([
    [matrix[0, 5], matrix[0, 1], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 5], matrix[1, 1], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 5], matrix[2, 1], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 5], matrix[3, 1], matrix[3, 2], matrix[3, 3]]
])
D5_determinant = np.linalg.det(D5_matrix)

# %%
D9_matrix = np.array([
    [matrix[0, 6], matrix[0, 1], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 6], matrix[1, 1], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 6], matrix[2, 1], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 6], matrix[3, 1], matrix[3, 2], matrix[3, 3]]
])
D9_determinant = np.linalg.det(D9_matrix)

# %%
D2_matrix = np.array([
    [matrix[0, 0], matrix[0, 4], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 4], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 4], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 4], matrix[3, 2], matrix[3, 3]]
])
D2_determinant = np.linalg.det(D2_matrix)

# %%
D6_matrix = np.array([
    [matrix[0, 0], matrix[0, 5], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 5], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 5], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 5], matrix[3, 2], matrix[3, 3]]
])
D6_determinant = np.linalg.det(D6_matrix)

# %%
D10_matrix = np.array([
    [matrix[0, 0], matrix[0, 6], matrix[0, 2], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 6], matrix[1, 2], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 6], matrix[2, 2], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 6], matrix[3, 2], matrix[3, 3]]
])
D10_determinant = np.linalg.det(D10_matrix)

# %%
D3_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 4], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 4], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 4], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 4], matrix[3, 3]]
])
D3_determinant = np.linalg.det(D3_matrix)

# %%
D7_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 5], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 5], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 5], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 5], matrix[3, 3]]
])
D7_determinant = np.linalg.det(D7_matrix)

# %%
D11_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 6], matrix[0, 3]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 6], matrix[1, 3]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 6], matrix[2, 3]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 6], matrix[3, 3]]
])
D11_determinant = np.linalg.det(D11_matrix)

# %%
D4_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 2], matrix[0, 4]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 2], matrix[1, 4]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 2], matrix[2, 4]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 2], matrix[3, 4]]
])
D4_determinant = np.linalg.det(D4_matrix)

# %%
D8_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 2], matrix[0, 5]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 2], matrix[1, 5]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 2], matrix[2, 5]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 2], matrix[3, 5]]
])
D8_determinant = np.linalg.det(D8_matrix)

# %%
D12_matrix = np.array([
    [matrix[0, 0], matrix[0, 1], matrix[0, 2], matrix[0, 6]],
    [matrix[1, 0], matrix[1, 1], matrix[1, 2], matrix[1, 6]],
    [matrix[2, 0], matrix[2, 1], matrix[2, 2], matrix[2, 6]],
    [matrix[3, 0], matrix[3, 1], matrix[3, 2], matrix[3, 6]]
])
D12_determinant = np.linalg.det(D12_matrix)

# %%
C0_CBM = round(D1_determinant/D_determinant, 6)
A_CBM = round(D2_determinant/D_determinant, 6)
B_CBM = round(D3_determinant/D_determinant, 6)
C_CBM = round(D4_determinant/D_determinant, 6)
print("C0_CBM = " + str(C0_CBM) + " , A_CBM = " + str(A_CBM) + " , B_CBM = " + str(B_CBM) + " , C_CBM = " + str(C_CBM))
# Out:
# C0_CBM = 4.331525 , A_CBM = -0.086912 , B_CBM = 0.029313 , C_CBM = -0.006756

# %%
C0_VBM = round(D5_determinant/D_determinant, 6)
A_VBM = round(D6_determinant/D_determinant, 6)
B_VBM = round(D7_determinant/D_determinant, 6)
C_VBM = round(D8_determinant/D_determinant, 6)
print("C0_VBM = " + str(C0_VBM) + " , A_VBM = " + str(A_VBM) + " , B_VBM = " + str(B_VBM) + " , C_VBM = " + str(C_VBM))
# Out:
# C0_VBM = 4.8945 , A_VBM = -0.02325 , B_VBM = 0.006025 , C_VBM = 0.000637

# %%
C0_d = round(D9_determinant/D_determinant, 6)
A_d = round(D10_determinant/D_determinant, 6)
B_d = round(D11_determinant/D_determinant, 6)
C_d = round(D12_determinant/D_determinant, 6)

# %%
# 绘制周期势能图CBM
# 定义一个二维网格
s = np.linspace(-0.5, 0.5, 100)
t = np.linspace(-0.5, 0.5, 100)
s, t = np.meshgrid(s, t)

# 定义势能函数，这里使用一个简单的例子
def potential_energy(x, y):
    return -(C0_CBM + 2 * A_CBM * np.cos(2 * np.pi * s) + 2 * B_CBM * np.cos(2 * np.pi * t) + 4 * C_CBM * np.cos(2 * np.pi * s) * np.cos(2 * np.pi * t))

# 计算势能值
z = potential_energy(s, t)

# 创建一个三维图形
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制势能图
ax.plot_surface(s, t, z, cmap='viridis')

# 设置坐标轴标签
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Energy (eV)')

# 显示图形
plt.show()

# %%
# 绘制CBM热图
plt.imshow(z, cmap='jet', extent=[-5, 5, -5, 5], origin='lower', aspect='auto')

# 添加颜色条
plt.colorbar()

# 添加坐标轴标签
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 添加标题
plt.title('CBM (eV)')

# 显示图像
plt.show()

# %%
# 绘制周期势能图VBM
# 定义一个二维网格
s = np.linspace(-0.5, 0.5, 100)
t = np.linspace(-0.5, 0.5, 100)
s, t = np.meshgrid(s, t)

# 定义势能函数，这里使用一个简单的例子
def potential_energy(x, y):
    return -(C0_VBM + 2 * A_VBM * np.cos(2 * np.pi * s) + 2 * B_VBM * np.cos(2 * np.pi * t) + 4 * C_VBM * np.cos(2 * np.pi * s) * np.cos(2 * np.pi * t))

# 计算势能值
z = potential_energy(s, t)

# 创建一个三维图形
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# 绘制势能图
ax.plot_surface(s, t, z, cmap='viridis')

# 设置坐标轴标签
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Energy (eV)')

# 显示图形
plt.show()

# %%
# 绘制VBM热图
plt.imshow(z, cmap='jet', extent=[-5, 5, -5, 5], origin='lower', aspect='auto')

# 添加颜色条
plt.colorbar()

# 添加坐标轴标签
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 添加标题
plt.title('VBM (eV)')

# 显示图像
plt.show()

# %%
# 生成层间距的热图
# 定义一个二维网格
s = np.linspace(-0.5, 0.5, 100)
t = np.linspace(-0.5, 0.5, 100)
s, t = np.meshgrid(s, t)

# 定义势能函数，这里使用一个简单的例子
def potential_energy(x, y):
    return (C0_d + 2 * A_d * np.cos(2 * np.pi * s) + 2 * B_d * np.cos(2 * np.pi * t) + 4 * C_d * np.cos(2 * np.pi * s) * np.cos(2 * np.pi * t))

# 计算势能值
z = potential_energy(s, t)


# 绘制热图
plt.imshow(z, cmap='jet', extent=[-5, 5, -5, 5], origin='lower', aspect='auto')

# 添加颜色条
plt.colorbar()

# 添加坐标轴标签
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# 添加标题
plt.title('The interlayer distance (A)')

# 显示图像
plt.show()
